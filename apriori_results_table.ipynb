# %% [markdown]
# <a href="https://colab.research.google.com/github/parmeeta2/HTFA09/blob/main/apriori_results_table.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
apriori_table_df = pd.read_csv('apriori_table_summary_all_categories.csv')
apriori_table_df
# Out:
#                      Column1  \
# 0                   Category
# 1                     Videos
# 2                     Videos
# 3                      Music
# 4                      Music
# 5                Video Games
# 6                Video Games
# 7                    Watches
# 8                    Watches
# 9            Office Products
# 10           Office Products
# 11                   Apparel
# 12  Personal Care Appliances
# 13                 Furniture
# 14                 Furniture
# 15  Personal Care Appliances
# 16                   Apparel
# 17                  Category
#
#                                               Column2  \
# 0                                      Antecedents ID
# 1                  0788802194, 0788812408, 0788812807
# 2   0788812408, 155890641X, 0788802194, 6304401132...
# 3                              B007ZRZWOA, B001BKVWYG
# 4                  B003GAMPWM, B009G7ZYPY, B00F0O8SZK
# 5                              B00BGA9X9W, B00JK00S0S
# 6                              B00BGA9X9W, B00BI83EVU
# 7                              B004P0UUE2, B005KKLEWS
# 8                              B003EKIS4S, B003EKNMAI
# 9                                          B007VBXB48
# 10                             B003H2GBM4, B00CIDQ470
# 11                                         B00817DYUM
# 12                                         B004O25RM6
# 13                                         B004UMDLPK
# 14                                         B006MIPW70
# 15                                         B004O23YE4
# 16                                         B0083QLPY8
# 17                                     Antecedents ID
#
#                                               Column3  \
# 0                                   Antecedents Names
# 1   Cinderella [VHS], The Little Mermaid [VHS], La...
# 2   The Little Mermaid [VHS], Snow White and the S...
# 3                  Searching For Sugar Man, Cold Fact
# 4   Susan Boyle - The Gift, Susan Boyle - Standing...
# 5   DualShock 4 Wireless Controller for PlayStatio...
# 6   DualShock 4 Wireless Controller for PlayStatio...
# 7   XOXO Women's XO5302A Rhinestone-Accented Gold-...
# 8   U.S. Polo Assn. Sport Men's US8170 Black and G...
# 9   Scotch Thermal Laminating Pouches, 100-Pack, 8...
# 10  HP 61 | Ink Cartridge | Black , HP Envy 4500 W...
# 11  Fruit of the Loom Men's Pocket Crew Neck Multi...
# 12                  doTERRA - White Fir Essential Oil
# 13     Furinno Coffee Table with Bins, Espresso/Brown
# 14  ZINUS SmartBase Zero Assembly Mattress Foundat...
# 15  doTERRA - DigestZen Essential Oil Digestive Bl...
# 16  Maidenform Women's Two-Hook 3/4 Inch Bra Extender
# 17                                  Antecedents Names
#
#                                Column4  \
# 0                      Consequents IDS
# 1   6304401132, 0788805533, 0788806270
# 2                           6300274195
# 3                           B001TCHDPS
# 4                           B005G618JU
# 5                           B00BGA9WK2
# 6                           B00BGA9WK2
# 7                           B004P0UUBK
# 8                           B008D902Q2
# 9                           B0010JEJPC
# 10                          B003YT6RNS
# 11                          B00817DZWO
# 12                          B004O25RJ4
# 13                          B004UME2PS
# 14                          B004LQ1RJ2
# 15                          B004O276PW
# 16                          B0083QLQ0G
# 17                     Consequents IDS
#
#                                               Column5      Column6
# 0                                   Consequents Names   Confidence
# 1   Sleeping Beauty [VHS], The Lion King II [VHS],...            1
# 2                                         Dumbo [VHS]            1
# 3                                 Coming from Reality  0.815384615
# 4             Susan Boyle - Someone To Watch Over Me           0.8
# 5                         PlayStation 4 500GB Console  0.551724138
# 6                         PlayStation 4 500GB Console  0.523809524
# 7   XOXO Women's XO5301A Rhinestone-Accented Silve...  0.444444444
# 8   U.S. Polo Assn. Sport Men's US9061 Watch with ...  0.428571429
# 9   Scotch Thermal Laminator, 2 Roller System for ...  0.428223844
# 10       HP 61 | 2 Ink Cartridges | Black, Tri-color      0.390625
# 11  Fruit of the Loom Men's Pocket Crew Neck T-Shi...  0.182432432
# 12           doTERRA - Rosemary Essential Oil - 15 Ml  0.161290323
# 13  Furinno End Table Bedroom Night Stand w/Bin Dr...  0.126279863
# 14  Signature Sleep Contour 8" Reversible Mattress...  0.113157895
# 15                  doTERRA - PastTense Essential Oil  0.088235294
# 16         Maidenform Women's Three-Hook Bra Extender  0.084699454
# 17                                  Consequents Names   Confidence

# %%
apriori_table_df.style.format({'Confidence': '{:,.2f}'.format})
# Out:
# <style type="text/css">
# </style>
# <table id="T_155b2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_155b2_level0_col0" class="col_heading level0 col0" >Column1</th>
#       <th id="T_155b2_level0_col1" class="col_heading level0 col1" >Column2</th>
#       <th id="T_155b2_level0_col2" class="col_heading level0 col2" >Column3</th>
#       <th id="T_155b2_level0_col3" class="col_heading level0 col3" >Column4</th>
#       <th id="T_155b2_level0_col4" class="col_heading level0 col4" >Column5</th>
#       <th id="T_155b2_level0_col5" class="col_heading level0 col5" >Column6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_155b2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_155b2_row0_col0" class="data row0 col0" >Category</td>
#       <td id="T_155b2_row0_col1" class="data row0 col1" >Antecedents ID</td>
#       <td id="T_155b2_row0_col2" class="data row0 col2" >Antecedents Names</td>
#       <td id="T_155b2_row0_col3" class="data row0 col3" >Consequents IDS</td>
#       <td id="T_155b2_row0_col4" class="data row0 col4" >Consequents Names</td>
#       <td id="T_155b2_row0_col5" class="data row0 col5" >Confidence</td>
#     </tr>
#     <tr>
#       <th id="T_155b2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_155b2_row1_col0" class="data row1 col0" >Videos</td>
#       <td id="T_155b2_row1_col1" class="data row1 col1" >0788802194, 0788812408, 0788812807</td>
#       <td id="T_155b2_row1_col2" class="data row1 col2" >Cinderella [VHS], The Little Mermaid [VHS], Lady and the Tramp [VHS]</td>
#       <td id="T_155b2_row1_col3" class="data row1 col3" >6304401132, 0788805533, 0788806270</td>
#       <td id="T_155b2_row1_col4" class="data row1 col4" >Sleeping Beauty [VHS], The Lion King II [VHS], Bambi [VHS]</td>
#       <td id="T_155b2_row1_col5" class="data row1 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_155b2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_155b2_row2_col0" class="data row2 col0" >Videos</td>
#       <td id="T_155b2_row2_col1" class="data row2 col1" >0788812408, 155890641X, 0788802194, 6304401132, 0788812807</td>
#       <td id="T_155b2_row2_col2" class="data row2 col2" >The Little Mermaid [VHS], Snow White and the Seven Dwarfs [VHS], Cinderella [VHS],  Sleeping Beauty [VHS], Lady and the Tramp [VHS]</td>
#       <td id="T_155b2_row2_col3" class="data row2 col3" >6300274195</td>
#       <td id="T_155b2_row2_col4" class="data row2 col4" >Dumbo [VHS]</td>
#       <td id="T_155b2_row2_col5" class="data row2 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_155b2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_155b2_row3_col0" class="data row3 col0" >Music</td>
#       <td id="T_155b2_row3_col1" class="data row3 col1" >B007ZRZWOA, B001BKVWYG</td>
#       <td id="T_155b2_row3_col2" class="data row3 col2" >Searching For Sugar Man, Cold Fact</td>
#       <td id="T_155b2_row3_col3" class="data row3 col3" >B001TCHDPS</td>
#       <td id="T_155b2_row3_col4" class="data row3 col4" >Coming from Reality</td>
#       <td id="T_155b2_row3_col5" class="data row3 col5" >0.815384615</td>
#     </tr>
#     <tr>
#       <th id="T_155b2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_155b2_row4_col0" class="data row4 col0" >Music</td>
#       <td id="T_155b2_row4_col1" class="data row4 col1" >B003GAMPWM, B009G7ZYPY, B00F0O8SZK</td>
#       <td id="T_155b2_row4_col2" class="data row4 col2" >Susan Boyle - The Gift, Susan Boyle - Standing Ovation,  Susan Boyle - Home for Christmas </td>
#       <td id="T_155b2_row4_col3" class="data row4 col3" >B005G618JU</td>
#       <td id="T_155b2_row4_col4" class="data row4 col4" >Susan Boyle - Someone To Watch Over Me </td>
#       <td id="T_155b2_row4_col5" class="data row4 col5" >0.8</td>
#     </tr>
#     <tr>
#       <th id="T_155b2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_155b2_row5_col0" class="data row5 col0" >Video Games</td>
#       <td id="T_155b2_row5_col1" class="data row5 col1" >B00BGA9X9W, B00JK00S0S</td>
#       <td id="T_155b2_row5_col2" class="data row5 col2" >DualShock 4 Wireless Controller for PlayStation 4 - Jet Black, PlayStation 4 500GB Console</td>
#       <td id="T_155b2_row5_col3" class="data row5 col3" >B00BGA9WK2</td>
#       <td id="T_155b2_row5_col4" class="data row5 col4" >PlayStation 4 500GB Console</td>
#       <td id="T_155b2_row5_col5" class="data row5 col5" >0.551724138</td>
#     </tr>
#     <tr>
#       <th id="T_155b2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_155b2_row6_col0" class="data row6 col0" >Video Games</td>
#       <td id="T_155b2_row6_col1" class="data row6 col1" >B00BGA9X9W, B00BI83EVU</td>
#       <td id="T_155b2_row6_col2" class="data row6 col2" >DualShock 4 Wireless Controller for PlayStation 4 - Jet Black, Watch Dogs - PlayStation 4</td>
#       <td id="T_155b2_row6_col3" class="data row6 col3" >B00BGA9WK2</td>
#       <td id="T_155b2_row6_col4" class="data row6 col4" >PlayStation 4 500GB Console</td>
#       <td id="T_155b2_row6_col5" class="data row6 col5" >0.523809524</td>
#     </tr>
#     <tr>
#       <th id="T_155b2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_155b2_row7_col0" class="data row7 col0" >Watches</td>
#       <td id="T_155b2_row7_col1" class="data row7 col1" >B004P0UUE2, B005KKLEWS</td>
#       <td id="T_155b2_row7_col2" class="data row7 col2" >XOXO Women's XO5302A Rhinestone-Accented Gold-Tone Bracelet Watch, XOXO Women's XO5429 Rhinestone-Accented Two-Tone Bracelet Watch</td>
#       <td id="T_155b2_row7_col3" class="data row7 col3" >B004P0UUBK</td>
#       <td id="T_155b2_row7_col4" class="data row7 col4" >XOXO Women's XO5301A Rhinestone-Accented Silver-Tone Bracelet Watch</td>
#       <td id="T_155b2_row7_col5" class="data row7 col5" >0.444444444</td>
#     </tr>
#     <tr>
#       <th id="T_155b2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_155b2_row8_col0" class="data row8 col0" >Watches</td>
#       <td id="T_155b2_row8_col1" class="data row8 col1" >B003EKIS4S, B003EKNMAI</td>
#       <td id="T_155b2_row8_col2" class="data row8 col2" >U.S. Polo Assn. Sport Men's US8170 Black and Gunmetal-Tone Bracelet Watch, U.S. Polo Assn. Sport Men's US9057 Black Metal Watch with Orange Rubber Band</td>
#       <td id="T_155b2_row8_col3" class="data row8 col3" >B008D902Q2</td>
#       <td id="T_155b2_row8_col4" class="data row8 col4" >U.S. Polo Assn. Sport Men's US9061 Watch with Black Rubber Strap Watch</td>
#       <td id="T_155b2_row8_col5" class="data row8 col5" >0.428571429</td>
#     </tr>
#     <tr>
#       <th id="T_155b2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_155b2_row9_col0" class="data row9 col0" >Office Products</td>
#       <td id="T_155b2_row9_col1" class="data row9 col1" >B007VBXB48</td>
#       <td id="T_155b2_row9_col2" class="data row9 col2" >Scotch Thermal Laminating Pouches, 100-Pack, 8.9 x 11.4 Inches, Letter Size Sheets (TP3854-100)</td>
#       <td id="T_155b2_row9_col3" class="data row9 col3" >B0010JEJPC</td>
#       <td id="T_155b2_row9_col4" class="data row9 col4" >Scotch Thermal Laminator, 2 Roller System for a Professional Finish, Use for Home, Office or School, Suitable for use with Photos (TL901X)</td>
#       <td id="T_155b2_row9_col5" class="data row9 col5" >0.428223844</td>
#     </tr>
#     <tr>
#       <th id="T_155b2_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_155b2_row10_col0" class="data row10 col0" >Office Products</td>
#       <td id="T_155b2_row10_col1" class="data row10 col1" >B003H2GBM4, B00CIDQ470</td>
#       <td id="T_155b2_row10_col2" class="data row10 col2" >HP 61 | Ink Cartridge | Black , HP Envy 4500 Wireless All-in-One Color Photo Printer</td>
#       <td id="T_155b2_row10_col3" class="data row10 col3" >B003YT6RNS</td>
#       <td id="T_155b2_row10_col4" class="data row10 col4" >HP 61 | 2 Ink Cartridges | Black, Tri-color </td>
#       <td id="T_155b2_row10_col5" class="data row10 col5" >0.390625</td>
#     </tr>
#     <tr>
#       <th id="T_155b2_level0_r

# %%
# Rename Category as segment
apriori_table_df.rename(columns={'Category': 'segment'}, inplace=True)
apriori_table_df
# Out:
#                      Column1  \
# 0                   Category
# 1                     Videos
# 2                     Videos
# 3                      Music
# 4                      Music
# 5                Video Games
# 6                Video Games
# 7                    Watches
# 8                    Watches
# 9            Office Products
# 10           Office Products
# 11                   Apparel
# 12  Personal Care Appliances
# 13                 Furniture
# 14                 Furniture
# 15  Personal Care Appliances
# 16                   Apparel
# 17                  Category
#
#                                               Column2  \
# 0                                      Antecedents ID
# 1                  0788802194, 0788812408, 0788812807
# 2   0788812408, 155890641X, 0788802194, 6304401132...
# 3                              B007ZRZWOA, B001BKVWYG
# 4                  B003GAMPWM, B009G7ZYPY, B00F0O8SZK
# 5                              B00BGA9X9W, B00JK00S0S
# 6                              B00BGA9X9W, B00BI83EVU
# 7                              B004P0UUE2, B005KKLEWS
# 8                              B003EKIS4S, B003EKNMAI
# 9                                          B007VBXB48
# 10                             B003H2GBM4, B00CIDQ470
# 11                                         B00817DYUM
# 12                                         B004O25RM6
# 13                                         B004UMDLPK
# 14                                         B006MIPW70
# 15                                         B004O23YE4
# 16                                         B0083QLPY8
# 17                                     Antecedents ID
#
#                                               Column3  \
# 0                                   Antecedents Names
# 1   Cinderella [VHS], The Little Mermaid [VHS], La...
# 2   The Little Mermaid [VHS], Snow White and the S...
# 3                  Searching For Sugar Man, Cold Fact
# 4   Susan Boyle - The Gift, Susan Boyle - Standing...
# 5   DualShock 4 Wireless Controller for PlayStatio...
# 6   DualShock 4 Wireless Controller for PlayStatio...
# 7   XOXO Women's XO5302A Rhinestone-Accented Gold-...
# 8   U.S. Polo Assn. Sport Men's US8170 Black and G...
# 9   Scotch Thermal Laminating Pouches, 100-Pack, 8...
# 10  HP 61 | Ink Cartridge | Black , HP Envy 4500 W...
# 11  Fruit of the Loom Men's Pocket Crew Neck Multi...
# 12                  doTERRA - White Fir Essential Oil
# 13     Furinno Coffee Table with Bins, Espresso/Brown
# 14  ZINUS SmartBase Zero Assembly Mattress Foundat...
# 15  doTERRA - DigestZen Essential Oil Digestive Bl...
# 16  Maidenform Women's Two-Hook 3/4 Inch Bra Extender
# 17                                  Antecedents Names
#
#                                Column4  \
# 0                      Consequents IDS
# 1   6304401132, 0788805533, 0788806270
# 2                           6300274195
# 3                           B001TCHDPS
# 4                           B005G618JU
# 5                           B00BGA9WK2
# 6                           B00BGA9WK2
# 7                           B004P0UUBK
# 8                           B008D902Q2
# 9                           B0010JEJPC
# 10                          B003YT6RNS
# 11                          B00817DZWO
# 12                          B004O25RJ4
# 13                          B004UME2PS
# 14                          B004LQ1RJ2
# 15                          B004O276PW
# 16                          B0083QLQ0G
# 17                     Consequents IDS
#
#                                               Column5      Column6
# 0                                   Consequents Names   Confidence
# 1   Sleeping Beauty [VHS], The Lion King II [VHS],...            1
# 2                                         Dumbo [VHS]            1
# 3                                 Coming from Reality  0.815384615
# 4             Susan Boyle - Someone To Watch Over Me           0.8
# 5                         PlayStation 4 500GB Console  0.551724138
# 6                         PlayStation 4 500GB Console  0.523809524
# 7   XOXO Women's XO5301A Rhinestone-Accented Silve...  0.444444444
# 8   U.S. Polo Assn. Sport Men's US9061 Watch with ...  0.428571429
# 9   Scotch Thermal Laminator, 2 Roller System for ...  0.428223844
# 10       HP 61 | 2 Ink Cartridges | Black, Tri-color      0.390625
# 11  Fruit of the Loom Men's Pocket Crew Neck T-Shi...  0.182432432
# 12           doTERRA - Rosemary Essential Oil - 15 Ml  0.161290323
# 13  Furinno End Table Bedroom Night Stand w/Bin Dr...  0.126279863
# 14  Signature Sleep Contour 8" Reversible Mattress...  0.113157895
# 15                  doTERRA - PastTense Essential Oil  0.088235294
# 16         Maidenform Women's Three-Hook Bra Extender  0.084699454
# 17                                  Consequents Names   Confidence

# %%
# Export DF as json
apriori_table_df.to_json(r'apriori_table_data.json',orient='records')
